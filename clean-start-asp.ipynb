# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import re
import matplotlib as mpl
import scipy as sp
from pathlib import Path


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/amhs-messages/G3_117G_PG1.txt
# /kaggle/input/amhs-messages/G3_117G.txt

# %%
headers = ['Raw', 'DTG', 'From', 'To', 'TAMCN', 'Nomenclature', 'Qty', 'Exercise_Name']

# %%
msgs = ('/kaggle/input/amhs-messages/G3_117G_PG1.txt')
df = pd.read_csv(msgs, names = headers)
pd.set_option('display.max_colwidth', None)
df
# Out:
#                                                               Raw  DTG From  \
# 0                     RAAUZYUW RUJIAAA1945 1541804-UUUU--RHMCSUU.  NaN  NaN
# 1                                                   ZNR UUUUU ZDH  NaN  NaN
# 2                                                R 031746Z JUN 22  NaN  NaN
# 3                                                 FM MAG TWO NINE  NaN  NaN
# 4                                        TO CG SECOND MAW G THREE  NaN  NaN
# ..                                                            ...  ...  ...
# 137                     UNITS TASKED FOR DETAILED COORDINATION.//  NaN  NaN
# 138  5.  MAG-29 REQUESTS A RESPONSE TO THIS FOS NLT 25 JULY 22.//  NaN  NaN
# 139           6.  CONTACT POCS LISTED ABOVE WITH ANY QUESTIONS.//  NaN  NaN
# 140                                                            BT  NaN  NaN
# 141                                                         #1945  NaN  NaN
#
#       To  TAMCN  Nomenclature  Qty  Exercise_Name
# 0    NaN    NaN           NaN  NaN            NaN
# 1    NaN    NaN           NaN  NaN            NaN
# 2    NaN    NaN           NaN  NaN            NaN
# 3    NaN    NaN           NaN  NaN            NaN
# 4    NaN    NaN           NaN  NaN            NaN
# ..   ...    ...           ...  ...            ...
# 137  NaN    NaN           NaN  NaN            NaN
# 138  NaN    NaN           NaN  NaN            NaN
# 139  NaN    NaN           NaN  NaN            NaN
# 140  NaN    NaN           NaN  NaN            NaN
# 141  NaN    NaN           NaN  NaN            NaN
#
# [142 rows x 8 columns]
